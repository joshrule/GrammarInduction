# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
import roc
from sklearn.metrics import roc_curve, auc
import sys
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Data generated using
# ```
#  writePhase2 10000 5000 0.01 "experiments/cogsci2014/phase2_data.pl"
#  writePhase3 1000 50 0.01 "experiments/cogsci2014/phase3_data.pl"
# ```

# %%
import roc
sys.path.append("data/")
from test_data_1_23n1 import data as data1
from test_data_1_23n2 import data as data2
from test_data_1_23n3 import data as data3

# %%
auc, tpr, fpr, ax =  roc.run_roc(data1[:, 0], data1[:, 1])
ax.set_title("Testing on numbers 1-100 after training through phase 3.")
print "done"
# Out:
# Area under the ROC curve : 0.636568
# done

# %%
auc, tpr, fpr, ax =  roc.run_roc(data2[:, 0], data2[:, 1])
ax.set_title("Testing on numbers 1-1000 after training through phase 3.")
print "done"
# Out:
# Area under the ROC curve : 0.645000
# done

# %%
auc, tpr, fpr, ax =  roc.run_roc(data3[:, 0], data3[:, 1])
ax.set_title("Testing on succ 1-100 after training through phase 3.")
print "done"
# Out:
# Area under the ROC curve : 0.890000
# done
