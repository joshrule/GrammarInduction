# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
import roc
from sklearn.metrics import roc_curve, auc
import sys

# %%
# Phase 2 test data after running Phases1, 2, 3 
# Here, 3 is just number data
data = [[0.0, 1.0, 0.998325],
[0.0204082, 1.0, 0.998325],
[0.0408163, 1.0, 0.998325],
[0.0612245, 1.0, 0.998325],
[0.0816327, 1.0, 0.994975],
[0.102041, 1.0, 0.994975],
[0.122449, 1.0, 0.994975],
[0.142857, 1.0, 0.98995],
[0.163265, 1.0, 0.9866],
[0.183673, 1.0, 0.984925],
[0.204082, 0.975, 0.98325],
[0.22449, 0.975, 0.978224],
[0.244898, 0.975, 0.978224],
[0.265306, 0.975, 0.978224],
[0.285714, 0.975, 0.976549],
[0.306122, 0.95, 0.974874],
[0.326531, 0.925, 0.973199],
[0.346939, 0.925, 0.973199],
[0.367347, 0.925, 0.971524],
[0.387755, 0.9, 0.966499],
[0.408163, 0.9, 0.961474],
[0.428571, 0.85, 0.949749],
[0.44898, 0.85, 0.941374],
[0.469388, 0.8, 0.931323],
[0.489796, 0.775, 0.906198],
[0.510204, 0.75, 0.871022],
[0.530612, 0.7, 0.829146],
[0.55102, 0.7, 0.768844],
[0.571429, 0.7, 0.728643],
[0.591837, 0.65, 0.646566],
[0.612245, 0.65, 0.577889],
[0.632653, 0.625, 0.514238],
[0.653061, 0.575, 0.447236],
[0.673469, 0.575, 0.383585],
[0.693878, 0.525, 0.319933],
[0.714286, 0.425, 0.237856],
[0.734694, 0.3, 0.174204],
[0.755102, 0.225, 0.125628],
[0.77551, 0.125, 0.100503],
[0.795918, 0.125, 0.0619765],
[0.816327, 0.1, 0.038526],
[0.836735, 0.075, 0.0217755],
[0.857143, 0.05, 0.0100503],
[0.877551, 0.05, 0.0100503],
[0.897959, 0.025, 0.00670017],
[0.918367, 0.025, 0.00335008],
[0.938776, 0.025, 0.00335008],
[0.959184, 0.0, 0.00335008],
[0.979592, 0.0, 0.00335008],
[1.0, 0.0, 0.00167504]]
df = pd.DataFrame(data, columns=["thresh", "HR", "FAR"])

# %%
ax = fig.add_subplot(111)
ax = roc.roc_plot(df["HR"], df["FAR"])
# Out:
# /Library/Python/2.7/site-packages/pandas-0.13.1-py2.7-macosx-10.9-intel.egg/pandas/core/common.py:276: DeprecationWarning: numpy boolean negative (the unary `-` operator) is deprecated, use the bitwise_xor (the `^` operator) or the logical_xor function instead.
#   return -res

# %%
import roc
sys.path.append("data/")
from test_data_1_23 import data

# %%
roc.roc_plot(data[:, 0], data[:, 1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-66be015374c2> in <module>()
# ----> 1 roc.roc_plot(data[:, 0], data[:, 1])
#
# TypeError: list indices must be integers, not tuple

# %%
data
# Out:
# [[1, -10.1066],
#  [1, -7.9666],
#  [1, -7.60903],
#  [1, -6.35794],
#  [1, -8.97955],
#  [1, -6.66862],
#  [1, -8.12303],
#  [1, -7.51676],
#  [1, -8.12753],
#  [1, -5.30344],
#  [1, -7.33004],
#  [1, -7.21945],
#  [1, -7.61641],
#  [1, -9.16359],
#  [1, -4.33788],
#  [1, -7.0928],
#  [1, -6.05569],
#  [1, -7.94961],
#  [1, -8.10787],
#  [1, -7.97496],
#  [0, -8.19304],
#  [0, -7.01924],
#  [0, -8.61208],
#  [0, -7.87788],
#  [0, -8.45736],
#  [0, -7.82004],
#  [0, -8.0798],
#  [0, -8.96686],
#  [0, -7.8238],
#  [0, -9.66634],
#  [0, -9.88623],
#  [0, -10.0923],
#  [0, -10.891],
#  [0, -9.49566],
#  [0, -9.93069],
#  [0, -10.1334],
#  [0, -11.4442],
#  [0, -9.04144],
#  [0, -9.93523],
#  [0, -6.49323],
#  [0, -6.10346],
#  [0, -5.1475],
#  [0, -6.80488],
#  [0, -7.59447],
#  [0, -7.1182],
#  [0, -6.56334],
#  [0, -7.3639],
#  [0, -6.72707],
#  [0, -7.57982],
#  [0, -8.19684],
#  [0, -8.32129],
#  [0, -8.68412],
#  [0, -9.04382],
#  [0, -8.56954],
#  [0, -7.8973],
#  [0, -9.78431],
# ...
